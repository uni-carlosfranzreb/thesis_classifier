# %% [markdown]
# Plot the training loss per epoch. Training this model took about 11 hours.

# %%
from matplotlib import pyplot as plt

# %%
log_file = '../logs/training_1644599055.log'
test_losses, tr_losses, lr = [], [], []
next_lr = False
with open(log_file) as f:
  for line in f.readlines():
    if 'test' in line:
      test_losses.append(float(line.split(': ')[-1]))
      next_lr = True
    elif 'lr' in line and next_lr is True:
      lr.append(float(line.split(': ')[-1]))
      next_lr = False
    elif 'loss of epoch' in line:
      tr_losses.append(float(line.split(': ')[-1]))
test_losses
# Out:
# [0.017570147290825844,
#  0.01718735881149769,
#  0.017000088468194008,
#  0.016997257247567177,
#  0.016893429681658745,
#  0.016751382499933243,
#  0.01656542904675007,
#  0.01657034642994404,
#  0.016340645030140877,
#  0.016339778900146484,
#  0.01615198701620102,
#  0.016093431040644646,
#  0.01582091487944126,
#  0.01557974610477686,
#  0.015315509401261806,
#  0.015140742063522339,
#  0.014945895411074162,
#  0.01473996601998806,
#  0.014579381793737411]

# %%
plt.scatter(range(1, len(test_losses)+1), test_losses)
plt.plot(range(1, len(test_losses)+1), test_losses)
plt.xlabel('Epoch')
plt.ylabel('Avg. testing loss')
plt.xticks(range(1, len(test_losses)+1))
plt.show()

# %%
plt.scatter(range(1, len(tr_losses)+1), tr_losses)
plt.plot(range(1, len(tr_losses)+1), tr_losses)
plt.xlabel('Epoch')
plt.ylabel('Avg. training loss')
plt.xticks(range(1, len(tr_losses)+1))
plt.show()

# %%
plt.scatter(range(1, len(lr)+1), lr)
plt.plot(range(1, len(lr)+1), lr)
plt.xlabel('Epoch')
plt.ylabel('Learning rate')
plt.xticks(range(1, len(lr)+1))
plt.show()

# %%
lr
# Out:
# [0.225,
#  0.225,
#  0.2025,
#  0.2025,
#  0.18225000000000002,
#  0.18225000000000002,
#  0.16402500000000003,
#  0.16402500000000003,
#  0.14762250000000005,
#  0.14762250000000005,
#  0.13286025000000004,
#  0.13286025000000004,
#  0.11957422500000003,
#  0.11957422500000003,
#  0.10761680250000004,
#  0.10761680250000004,
#  0.09685512225000004,
#  0.09685512225000004]
